# %%
import ipywidgets as widgets
from ipywidgets import interact, interact_manual

# %%
inp1 = widgets.Dropdown(
    options=['slab1', 'slab2', 'sphere1', 'sphere2', 'sphere3'],
    value='slab1',
    # rows=10,
    description='file choice 1',
    disabled=False
)
inp2 = widgets.Dropdown(
    options=['slab1', 'slab2', 'sphere1', 'sphere2', 'sphere3'],
    value='slab2',
    # rows=10,
    description='file choice 2',
    disabled=False
)
inp3 = widgets.Dropdown(
    options=['slab1', 'slab2', 'sphere1', 'sphere2', 'sphere3'],
    value='sphere1',
    # rows=10,
    description='file choice 3',
    disabled=False
)
display(inp1, inp2, inp3)

print(inp1.value)
# Out:
# Dropdown(description='file choice 1', options=('slab1', 'slab2', 'sphere1', 'sphere2', 'sphere3'), value='slab…
# Dropdown(description='file choice 2', index=1, options=('slab1', 'slab2', 'sphere1', 'sphere2', 'sphere3'), va…
# Dropdown(description='file choice 3', index=2, options=('slab1', 'slab2', 'sphere1', 'sphere2', 'sphere3'), va…
# slab1

# %%
contents = [
    str(inp1.value),
    str(inp2.value),
    str(inp3.value)    
]
with open("dustyscratch.inp", "w", encoding="utf-8") as file:
    file.writelines('\n'.join(contents))
    print(contents)
# Out:
# ['sphere3', 'sphere3', 'slab1']
